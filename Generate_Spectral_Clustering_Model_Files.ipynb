# %%
# Import files
import os # system
# you can import files google drive through colab, adjusting the csv file path appropriately
#from google.colab import drive
#drive.mount('/content/drive')
#from google.colab import files

# %% [markdown]
# # Manual
# This notebook will retrain the model and export the appropriate files. Model retraining is only necessary if incorporating new datasets. Otherwise, the model and files in the application do not need to be updated.
#
# Follow the in line comments for pointers and tips.
#
# Setup:
#
# Install requirements.txt or use !pip install code provided in cells.
# Set up HuggingFace API Token in .env file or through notebook using os.environ["HUGGINGFACEHUB_API_TOKEN"] = 'your token'
#
# Adjust the CSV file path and append data as necessary.
#
# Manual tuning will be required. This occurs in the Spectral Clustering Tuning section, where the spectral clustering model is to be tuned based on the Silhouette Scores.
#
# File output is at the end of the notebook. The clustered csv, embeddings, similarity matrix, and FAISS index will be saved to your directory. You do not need to save the clustering model. The maximum total file size is 100 MB.
#
# This may take up to 30 minutes to initialize and an additional 15 minutes to tune and complete.
#
# This notebook was made through and can be run through Google CoLab, for free access to computing resources in your browser. Formatting may require adjustments.

# %% [markdown]
# # Import Libraries
# Define functions, import libraries and files.

# %%
# CSV File path, adjust as necessary based on your directory
csv_file ='data/isbndb-caribbean-books.csv'

# %%
# Provide HuggingFace API token
#os.environ["HUGGINGFACEHUB_API_TOKEN"] = 'your token'

# %%
# Install Libraries
import pandas as pd
import numpy as np
import pickle

# %%
# Model Libraries
from sklearn.cluster import SpectralClustering
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Metrics Libraries
# !pip install matplotlib
import matplotlib.pyplot as plt
import timeit
from sklearn.metrics import silhouette_score, davies_bouldin_score
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp39-cp39-macosx_10_12_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (164 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_10_9_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from matplotlib) (11.0.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp39-cp39-macosx_10_12_x86_64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 8.0 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (265 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.0-cp39-cp39-macosx_10_9_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 9.8 MB/s eta 0:00:00ta 0:00:01
# Downloading kiwisolver-1.4.7-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.55.0 kiwisolver-1.4.7 matplotlib-3.9.2 pyparsing-3.2.0
# Matplotlib is building the font cache; this may take a moment.

# %%
# Sentence Transformers and Langchain libraries
# !pip install chromadb langchain tiktoken sentence-transformers faiss-cpu
# !pip install langchain langchain_community
from langchain.llms import HuggingFaceHub
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma, FAISS
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.schema import Document # Import Document class

model = SentenceTransformer('all-MiniLM-L6-v2')
llm = HuggingFaceHub(repo_id = "microsoft/Phi-3-mini-4k-instruct", model_kwargs={"temperature":0.6})
# Out:
# Requirement already satisfied: chromadb in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (0.5.20)
# Requirement already satisfied: langchain in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (0.3.8)
# Requirement already satisfied: tiktoken in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (0.8.0)
# Requirement already satisfied: sentence-transformers in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (3.3.1)
# Requirement already satisfied: faiss-cpu in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: build>=1.0.3 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (2.10.1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (0.115.5)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.32.1)
# Requirement already satisfied: numpy>=1.22.5 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (3.7.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (1.28.2)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (4.67.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (1.68.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (0.13.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (3.11.7)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (0.3.21)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (0.1.145)
# Requirement already satisfied: requests<3,>=2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from sentence-transformers) (4.46.3)
# Requirement already satisfied: torch>=1.11.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.0)
# Requirement already satisfied: packaging>=19.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.5.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.1.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from fastapi>=0.95.2->chromadb) (0.41.3)
# Requirement already satisfied: anyio in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (4.6.2.post1)
# Requirement already satisfied: certifi in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: filelock in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: six>=1.9.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.36.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: coloredlogs in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (5.28.3)
# Requirement already satisfied: sympy in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-proto==1.28.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.49b2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-instrumentation==0.49b2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-util-http==0.49b2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: networkx in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: click>=8.0.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.21.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: langchain in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (0.3.8)
# Requirement already satisfied: langchain_community in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (0.3.8)
# Requirement already satisfied: PyYAML>=5.3 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (3.11.7)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (0.3.21)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (0.1.145)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (2.10.1)
# Requirement already satisfied: requests<3,>=2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain_community) (2.6.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: sniffio in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/kn/Documents/GitHub/venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# /var/folders/s3/5bwh4v9502n5d9pnr6s_3xqh0000gn/T/ipykernel_84063/3314628269.py:12: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   llm = HuggingFaceHub(repo_id = "microsoft/Phi-3-mini-4k-instruct", model_kwargs={"temperature":0.6})
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[6], line 12
#       9 from langchain.schema import Document # Import Document class
#      11 model = SentenceTransformer('all-MiniLM-L6-v2')
# ---> 12 llm = HuggingFaceHub(repo_id = "microsoft/Phi-3-mini-4k-instruct", model_kwargs={"temperature":0.6})
#
# File ~/Documents/GitHub/venv/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:216, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     214     warned = True
#     215     emit_warning()
# --> 216 return wrapped(self, *args, **kwargs)
#
# File ~/Documents/GitHub/venv/lib/python3.9/site-packages/langchain_core/load/serializable.py:125, in Serializable.__init__(self, *args, **kwargs)
#     123 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     124     """"""
# --> 125     super().__init__(*args, **kwargs)
#
# File ~/Documents/GitHub/venv/lib/python3.9/site-packages/pydantic/main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     219         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     220         stacklevel=2,
#     221     )
#
# ValidationError: 1 validation error for HuggingFaceHub
#   Value error, Did not find huggingfacehub_api_token, please add an environment variable `HUGGINGFACEHUB_API_TOKEN` which contains it, or pass `huggingfacehub_api_token` as a named parameter. [type=value_error, input_value={'repo_id': 'microsoft/Ph...acehub_api_token': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/value_error

# %%
# Language detection and translation functions
# !pip install langdetect
# !pip install deep_translator
from langdetect import detect, DetectorFactory
from langdetect.lang_detect_exception import LangDetectException
from deep_translator import GoogleTranslator

DetectorFactory.seed = 0

# Input language determinate
class LanguageDetector:
    def __init__(self, text=""):
        self.text = text

    def set_text(self, text):
        self.text = text

    def detect_language(self):
        try:
            language_code = detect(self.text)
            return language_code
        except LangDetectException:
            language_code = "en"
            return language_code

# Translate text to English
def translate_to_english(text):
    try:
        translated = GoogleTranslator(source='auto', target='en').translate(text)
        return translated
    except:
        return text

# %%
#Text Preprocessing
import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
import sys
# !{sys.executable} -m pip install contractions
import contractions

def preprocess(s):
    s=str(s)
    s = s.lower() # lowercase !
    s = contractions.fix(s) # expand contractions
    s = re.sub(r'\n', ' ', s) # remove \n
    s = re.sub(r'http\S+', '', s) # remove url
    s = re.sub(r'<.*?>', '', s) # remove html
    s = re.sub(r'\d+', '', s) # remove numbers
    s = re.sub(r'\s+', ' ', s).strip()
    s = re.sub(r'[^\w\s]', '', s) # remove punctuation and special characters
    s = word_tokenize(s) # tokenize
    s = [w for w in s if w not in set(stopwords.words('english'))] # stop words
    s = [stemmer.stem(w) for w in s] # stemming
    return " ".join(s) # white spaces

# %% [markdown]
# # Preprocess Data
# Clean and translate

# %%
# Import book data CSV
df = pd.read_csv(csv_file, encoding= 'latin1')

# %%
# Clean and preprocess data
df_match = df.copy()
# Remove duplicates
df_match.drop_duplicates(subset = 'title', inplace=True)
df_match.drop_duplicates(subset = 'synopsis', inplace=True)
# Remove independently published books and books missing publishers
df_match = df_match[~df_match['publisher'].str.contains("ndependent", na=False)]
df_match.dropna(subset='publisher', inplace=True)
# Remove books missing both subject and synopsis
df_match.dropna(subset=['subjects', 'synopsis'], inplace=True, how='all')
# Drop irrelevant columns
df_match.drop(['title_long', 'binding', 'pages', 'image', 'isbn', 'isbn10', 'isbn13', 'authors', 'msrp', 'edition', 'date_published'], axis=1, inplace=True)
# Filling missing data with empty strings
df_match['subjects'].fillna(value='', inplace=True)
df_match['synopsis'].fillna(value='', inplace=True)

# %%
# Detect languages and translate to English
detector = LanguageDetector()
for idx, row in df_match.iterrows():
    detector.set_text(row['synopsis'])
    detected_language = detector.detect_language()
    df_match.at[idx, 'language'] = detected_language
    df_match.at[idx, 'synopsis'] = translate_to_english(row['synopsis'])
    df_match.at[idx, 'subjects'] = translate_to_english(row['subjects'])

# %%
# df_match will be used to create FAISS index
# Dataframe for model, does not include publisher or language
df_model = df_match.copy()
df_model.drop(['publisher', 'language'], axis=1, inplace=True)

# %%
# Dataframe for matching publisher, will be used to integrate data with clustering results
df_publisher = df_match.copy()
df_publisher.reset_index(drop=True, inplace=True)

# %%
# Apply preprocessing to modeling dataframe
df_model=df_model.map(lambda s:preprocess(s)).copy()
df_model.reset_index(drop=True, inplace=True)

# %% [markdown]
# # SentenceTransformer Embeddings

# %%
# Generate separate embeddings for each column, may be used for multiview that analyze separately
expanded_subjects = "This text discusses " + df_model['subjects']
subjects_embeddings = model.encode(expanded_subjects.tolist(), batch_size=32, show_progress_bar=True)
synopsis_embeddings = model.encode(df_model['synopsis'].tolist(), batch_size=32, show_progress_bar=True)

# Subject:Synopsis = 9:1
weighted_embeddings = []
for subject, synopsis, subject_text in zip(subjects_embeddings, synopsis_embeddings, expanded_subjects):
    if subject_text.strip() == "":  # If `subject` is empty
        subject_weight = 0
        synopsis_weight = 1
    else:
        subject_weight = 0.9
        synopsis_weight = 0.1

    weighted_embedding = subject_weight * subject + synopsis_weight * synopsis
    weighted_embeddings.append(weighted_embedding)

weighted_embeddings = np.array(weighted_embeddings)

# %% [markdown]
# # Cosine Similarity Matrix

# %%
# cosine similarity matrix
similarity_matrix = cosine_similarity(weighted_embeddings)
# threshold --> create sparse matrix
threshold = np.percentile(similarity_matrix, 95)
similarity_matrix[similarity_matrix < threshold] = 0

# %% [markdown]
# # Spectral Clustering Tuning
# Select ideal cluster number based on Silhouette Scores.

# %%
# Visual analysis: Silhouette Score
# Graph Silhouette Scores. Closer to 1 is best.
# Determine ideal number of clusters at peak drop off
# Typically around 50 to 60
scores = []
# Adjust range to hone in on ideal clusters. range(start,stop,step)
cluster_range =range(50,100,5)
for n in cluster_range:
    start= timeit.default_timer()
    model = SpectralClustering(n_clusters=n, affinity='precomputed', assign_labels='discretize', random_state=42)
    cluster_labels = model.fit_predict(similarity_matrix)
    score = silhouette_score(similarity_matrix, cluster_labels, metric='cosine')
    scores.append(score)
    stop = timeit.default_timer()
    print(f"Silhouette Score for {n} clusters: {score} time: {stop - start}")

plt.plot(cluster_range, scores, marker='o')
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score Analysis for Optimal n_clusters")
plt.show()

# %%
# Tune final cluster model
# Select n_clusters based on Silhouette Score Analysis
# Typically from 50 to 60
spectral = SpectralClustering(
    n_clusters= 60, # Adjust number of clusters according to Silhouette Score Analysis
    affinity='precomputed',
    assign_labels='discretize',
    random_state=42
)

# %%
# Fit  and Predict Spectral Model onto Data
df_publisher['cluster'] = spectral.fit_predict(similarity_matrix)
silhouette_avg = silhouette_score(similarity_matrix, df_publisher['cluster'], metric='cosine')
davies_bouldin = davies_bouldin_score(weighted_embeddings, df_publisher['cluster'])
print("Silhouette Score: ", silhouette_avg) # Closer to 1 is best
print("Davies-Bouldin Score: ", davies_bouldin) # Lower is best

# %% [markdown]
# # FAISS Index
# This may produce a file index.csv, which can be discarded after.

# %%
# Load data
df_match.to_csv('index.csv',index=False)
loader = CSVLoader(file_path="index.csv")
data = loader.load()
# Transform data
text_splitter = CharacterTextSplitter(chunk_size=2500, chunk_overlap=0)
texts = text_splitter.split_documents(data)

# %%
#embeddings = HuggingFaceEmbeddings(model_name='bert-base-uncased')
embeddings = HuggingFaceEmbeddings(model_name='paraphrase-MiniLM-L6-v2')

# %%
# Fill Vector DB
docsearch = FAISS.from_documents(texts, embeddings)
retriever=docsearch.as_retriever()

# %% [markdown]
# # File Output
# All required model files are saved below.

# %%
# The Spectral Clustering Model does not need to be saved for the purposes of the application
# Save Spectral Model with Pickle
#with open('spectral_model.pkl', 'wb') as file:
#    pickle.dump(spectral, file)

# %%
# Save csv with cluster assignments
df_publisher.to_csv('df_spec_modeling.csv',index=False)

# %%
# Save similarity matrix and embeddings of data
np.save('similarity_matrix.npy', similarity_matrix)
np.save('weighted_embeddings.npy', weighted_embeddings)

# %%
# Save FAISS index, system requires both faiss and  pkl file
docsearch.save_local("faiss_index")
